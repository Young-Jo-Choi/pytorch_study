# %%
import os
import numpy as np

import torch
from torch import nn
from torch.nn import functional as F
from torch import optim
from torch.utils.data import DataLoader

from torchvision import datasets, models, transforms

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
def set_seed(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    np.random.seed(seed)
    torch.backends.cudnn.deterministic=True
    torch.backends.cudnn.benchmark=False
set_seed(42)

# %%
from source import cifar_dataloader
path = './../data/'
loader_dict = cifar_dataloader.get_cifar100_dataloader(path = path, batch_size=128)
train_loader = loader_dict['train']
val_loader = loader_dict['val']
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# # 일반 resenet50을 학습
# - loss : Cross-Entropy

# %%
model = models.resnet18(pretrained=False)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)
criterion = nn.CrossEntropyLoss()
epochs = 500

model = model.to(device)

# %%
# early stopping
from source import EarlyStopping
from source import functions

early_stopping = EarlyStopping.EarlyStopping(patience=20, verbose=False)
model_ft, hist = functions.train_model(
    model = model, 
    dataloaders = loader_dict, 
    criterion = criterion, 
    optimizer = optimizer, 
    device=device, 
    num_epochs=epochs, 
    early_stop = early_stopping
    )
# Out:
# Epoch 0/499
# ----------
# train Loss: 4.7830 Acc: 0.0601
# val Loss: 4.0622 Acc: 0.0955
#
# Epoch 1/499
# ----------
# train Loss: 3.9684 Acc: 0.1043
# val Loss: 3.8294 Acc: 0.1263
#
# Epoch 2/499
# ----------
# train Loss: 3.8180 Acc: 0.1242
# val Loss: 3.6893 Acc: 0.1419
#
# Epoch 3/499
# ----------
# train Loss: 3.7269 Acc: 0.1354
# val Loss: 3.6308 Acc: 0.1497
#
# Epoch 4/499
# ----------
# train Loss: 3.6545 Acc: 0.1489
# val Loss: 3.5383 Acc: 0.1662
#
# Epoch 5/499
# ----------
# train Loss: 3.5927 Acc: 0.1593
# val Loss: 3.4460 Acc: 0.1866
#
# Epoch 6/499
# ----------
# train Loss: 3.5335 Acc: 0.1716
# val Loss: 3.3843 Acc: 0.2031
#
# Epoch 7/499
# ----------
# train Loss: 3.4802 Acc: 0.1791
# val Loss: 3.3208 Acc: 0.2105
#
# Epoch 8/499
# ----------
# train Loss: 3.4183 Acc: 0.1907
# val Loss: 3.2849 Acc: 0.2138
#
# Epoch 9/499
# ----------
# train Loss: 3.3679 Acc: 0.1992
# val Loss: 3.2079 Acc: 0.2281
#
# Epoch 10/499
# ----------
# train Loss: 3.3331 Acc: 0.2052
# val Loss: 3.1790 Acc: 0.2301
#
# Epoch 11/499
# ----------
# train Loss: 3.2742 Acc: 0.2149
# val Loss: 3.1108 Acc: 0.2446
#
# Epoch 12/499
# ----------
# train Loss: 3.2437 Acc: 0.2206
# val Loss: 3.0725 Acc: 0.2527
#
# Epoch 13/499
# ----------
# train Loss: 3.2092 Acc: 0.2262
# val Loss: 3.0257 Acc: 0.2643
#
# Epoch 14/499
# ----------
# train Loss: 3.1665 Acc: 0.2366
# val Loss: 3.0000 Acc: 0.2662
#
# Epoch 15/499
# ----------
# train Loss: 3.1235 Acc: 0.2431
# val Loss: 2.9401 Acc: 0.2803
#
# Epoch 16/499
# ----------
# train Loss: 3.0962 Acc: 0.2461
# val Loss: 2.9072 Acc: 0.2842
#
# Epoch 17/499
# ----------
# train Loss: 3.0533 Acc: 0.2567
# val Loss: 2.8962 Acc: 0.2856
#
# Epoch 18/499
# ----------
# train Loss: 3.0212 Acc: 0.2624
# val Loss: 2.8218 Acc: 0.2965
#
# Epoch 19/499
# ----------
# train Loss: 2.9907 Acc: 0.2689
# val Loss: 2.8463 Acc: 0.2978
# EarlyStopping counter: 1 out of 20
#
# Epoch 20/499
# ----------
# train Loss: 2.9480 Acc: 0.2790
# val Loss: 2.7387 Acc: 0.3223
#
# Epoch 21/499
# ----------
# train Loss: 2.9170 Acc: 0.2822
# val Loss: 2.7167 Acc: 0.3242
#
# Epoch 22/499
# ----------
# train Loss: 2.8823 Acc: 0.2901
# val Loss: 2.7728 Acc: 0.3125
# EarlyStopping counter: 1 out of 20
#
# Epoch 23/499
# ----------
# train Loss: 2.8559 Acc: 0.2926
# val Loss: 2.6522 Acc: 0.3321
#
# Epoch 24/499
# ----------
# train Loss: 2.8199 Acc: 0.3009
# val Loss: 2.6007 Acc: 0.3440
#
# Epoch 25/499
# ----------
# train Loss: 2.7755 Acc: 0.3099
# val Loss: 2.5945 Acc: 0.3489
#
# Epoch 26/499
# ----------
# train Loss: 2.7459 Acc: 0.3148
# val Loss: 2.5228 Acc: 0.3569
#
# Epoch 27/499
# ----------
# train Loss: 2.7254 Acc: 0.3180
# val Loss: 2.5308 Acc: 0.3569
# EarlyStopping counter: 1 out of 20
#
# Epoch 28/499
# ----------
# train Loss: 2.6794 Acc: 0.3277
# val Loss: 2.5497 Acc: 0.3538
# EarlyStopping counter: 2 out of 20
#
# Epoch 29/499
# ----------
# train Loss: 2.6603 Acc: 0.3334
# val Loss: 2.4826 Acc: 0.3732
#
# Epoch 30/499
# ----------
# train Loss: 2.6232 Acc: 0.3407
# val Loss: 2.3905 Acc: 0.3845
#
# Epoch 31/499
# ----------
# train Loss: 2.5925 Acc: 0.3466
# val Loss: 2.4025 Acc: 0.3882
# EarlyStopping counter: 1 out of 20
#
# Epoch 32/499
# ----------
# train Loss: 2.5667 Acc: 0.3519
# val Loss: 2.3237 Acc: 0.4017
#
# Epoch 33/499
# ----------
# train Loss: 2.5404 Acc: 0.3592
# val Loss: 2.3877 Acc: 0.3858
# EarlyStopping counter: 1 out of 20
#
# Epoch 34/499
# ----------
# train Loss: 2.5148 Acc: 0.3611
# val Loss: 2.3129 Acc: 0.4077
#
# Epoch 35/499
# ----------
# train Loss: 2.4847 Acc: 0.3666
# val Loss: 2.2569 Acc: 0.4130
#
# Epoch 36/499
# ----------
# train Loss: 2.4592 Acc: 0.3741
# val Loss: 2.2641 Acc: 0.4154
# EarlyStopping counter: 1 out of 20
#
# Epoch 37/499
# ----------
# train Loss: 2.4303 Acc: 0.3799
# val Loss: 2.2999 Acc: 0.4118
# EarlyStopping counter: 2 out of 20
#
# Epoch 38/499
# ----------
# train Loss: 2.4136 Acc: 0.3823
# val Loss: 2.1798 Acc: 0.4336
#
# Epoch 39/499
# ----------
# train Loss: 2.3804 Acc: 0.3918
# val Loss: 2.1854 Acc: 0.4322
# EarlyStopping counter: 1 out of 20
#
# Epoch 40/499
# ----------
# train Loss: 2.3505 Acc: 0.3986
# val Loss: 2.1818 Acc: 0.4330
# EarlyStopping counter: 2 out of 20
#
# Epoch 41/499
# ----------
# train Loss: 2.3410 Acc: 0.3988
# val Loss: 2.1228 Acc: 0.4427
#
# Epoch 42/499
# ----------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 6
#       3 from source import functions
#       5 early_stopping = EarlyStopping.EarlyStopping(patience=20, verbose=False)
# ----> 6 model_ft, hist = functions.train_model(
#       7     model = model,
#       8     dataloaders = loader_dict,
#       9     criterion = criterion,
#      10     optimizer = optimizer,
#      11     device=device,
#      12     num_epochs=epochs,
#      13     early_stop = early_stopping
#      14     )
#
# File ~/pytorch_study/source/functions.py:107, in train_model(model, dataloaders, criterion, optimizer, device, num_epochs, is_inception, early_stop)
#     105 for inputs, labels in dataloaders[phase]:
#     106     inputs = inputs.to(device)
# --> 107     labels = labels.to(device)
#     109     # zero the parameter gradients
#     110     optimizer.zero_grad()
#
# KeyboardInterrupt:
